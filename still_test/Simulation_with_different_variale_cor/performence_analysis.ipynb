# %%
import numpy as np 
import pandas as pd

performence_results = pd.read_csv(r"C:\Users\cyguo\Desktop\lai_jun_yan\碩論\Deep_glm\still_test\Simulation_with_different_variale_cor\performance_results.csv")

# %%
print(performence_results.head())
print(len(performence_results))
# Out:
#    Simulation   OLS_MSE  Ridge_MSE  Lasso_MSE  DeepGLM_MSE  OLS_RMSE  \
# 0           1  0.942604   0.942976   0.942623     0.940537  0.970878
# 1           2  0.934662   0.941833   0.935341     0.935850  0.966779
# 2           3  1.037436   1.038348   1.036696     1.040059  1.018546
# 3           4  0.976505   0.970164   0.976453     0.974688  0.988183
# 4           5  1.005682   1.023306   1.005767     1.006812  1.002837
#
#    Ridge_RMSE  Lasso_RMSE  DeepGLM_RMSE    OLS_R2  Ridge_R2  Lasso_R2  \
# 0    0.971069    0.970888      0.969813  0.959801  0.959785  0.959800
# 1    0.970481    0.967130      0.967394  0.963785  0.963507  0.963758
# 2    1.018994    1.018183      1.019833  0.964917  0.964886  0.964942
# 3    0.984969    0.988156      0.987263  0.962950  0.963191  0.962952
# 4    1.011586    1.002879      1.003400  0.964297  0.963671  0.964294
#
#    DeepGLM_R2
# 0    0.959889
# 1    0.963738
# 2    0.964828
# 3    0.963019
# 4    0.964256
# 500

# %%
print(performence_results[
    ["OLS_MSE", "Ridge_MSE", "Lasso_MSE", "DeepGLM_MSE"]
].mean())
# Out:
# OLS_MSE        1.014314
# Ridge_MSE      1.014482
# Lasso_MSE      1.014198
# DeepGLM_MSE    1.014103
# dtype: float64

# %%
from scipy.stats import ttest_rel

models = ["OLS", "Ridge", "Lasso"]

for model in models:

    diff = (
        performence_results["DeepGLM_MSE"]
        - performence_results[f"{model}_MSE"]
    )

    result = ttest_rel(
        performence_results["DeepGLM_MSE"],
        performence_results[f"{model}_MSE"],
        alternative="less"
    )

    print(f"\nDeepGLM vs {model}")
    print(f"Mean difference = {diff.mean():.6f}")
    print(f"SD difference   = {diff.std():.6f}")
    print(f"t-statistic     = {result.statistic:.4f}")
    print(f"p-value         = {result.pvalue:.6g}")
# Out:
# DeepGLM vs OLS
# Mean difference = -0.000210
# SD difference   = 0.003065
# t-statistic     = -1.5351
# p-value         = 0.0626953
#
# DeepGLM vs Ridge
# Mean difference = -0.000379
# SD difference   = 0.003585
# t-statistic     = -2.3662
# p-value         = 0.00917698
#
# DeepGLM vs Lasso
# Mean difference = -0.000095
# SD difference   = 0.002914
# t-statistic     = -0.7283
# p-value         = 0.233392
